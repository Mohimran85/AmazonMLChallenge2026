# %%
# !nvidia-smi
# Out:
# Thu Sep 24 17:00:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/Mohimran85/AmazonMLChallenge2026.git
# Out:
# Cloning into 'AmazonMLChallenge2026'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import userdata

token = userdata.get("GITHUB_TOKEN")

print("Token loaded:", token is not None)
# Out:
# Token loaded: True

# %%
from google.colab import userdata
import subprocess

token = userdata.get("GITHUB_TOKEN")

subprocess.run([
    "git", "clone",
    f"https://Mohimran85:{token}@github.com/Mohimran85/AmazonMLChallenge2026.git"
], check=True)
# Out:
# CompletedProcess(args=['git', 'clone', 'https://Mohimran85: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@github.com/Mohimran85/AmazonMLChallenge2026.git'], returncode=0)

# %%
# %cd AmazonMLChallenge2026
# Out:
# /content/AmazonMLChallenge2026

# %%
# !ls
# Out:
# data  notebooks  README.md  requirements.txt  src

# %%
# !nvidia-smi
# Out:
# Thu Sep 24 17:18:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 82.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.9 MB/s eta 0:00:00
# ...
# Using cached anyio-4.15.1-py3-none-any.whl (132 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.9/109.9 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.6/250.6 kB 24.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import sklearn
import xgboost
import lightgbm
import catboost

print("✅ ML environment ready!")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("XGBoost:", xgboost.__version__)
print("LightGBM:", lightgbm.__version__)
print("CatBoost:", catboost.__version__)
# Out:
# ✅ ML environment ready!
# Pandas: 2.2.3
# NumPy: 2.1.3
# Scikit-learn: 1.6.1
# XGBoost: 3.4.1
# LightGBM: 4.6.0
# CatBoost: 1.2.10

# %%
# !pip install -q pandas numpy scipy scikit-learn matplotlib seaborn xgboost lightgbm catboost

# %%
# !cd /content/AmazonMLChallenge2026 && git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !cd /content/AmazonMLChallenge2026 && git remote -v
# Out:
# origin	https://Mohimran85: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@github.com/Mohimran85/AmazonMLChallenge2026.git (fetch)
# origin	https://Mohimran85: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@github.com/Mohimran85/AmazonMLChallenge2026.git (push)

# %%
# !find /content/AmazonMLChallenge2026 -maxdepth 3 -name "*.ipynb"

# %%
# !find /content/AmazonMLChallenge2026 -name "*.ipynb" -maxdepth 3
# Out:
# find: warning: you have specified the global option -maxdepth after the argument -name, but global options are not positional, i.e., -maxdepth affects tests specified before it as well as those specified after it.  Please specify global options before other arguments.

# %%
# !find /content/AmazonMLChallenge2026 -maxdepth 3 -name "*.ipynb"

# %%
# !cd /content/AmazonMLChallenge2026 && git remote set-url origin https://github.com/Mohimran85/AmazonMLChallenge2026.git
